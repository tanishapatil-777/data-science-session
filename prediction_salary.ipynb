# %%
price=1000
discount=0.2
tax=0.18
final_price=price-(price*discount)
print("final price after discount",final_price)
# Out:
# final price after discount 800.0

# %%
price=1000
discount=0.2
tax=0.18
final_price=price-(price*discount)
final_price=final_price+(final_price*tax)
print("final price after discount:",final_price)
# Out:
# final price after discount: 944.0

# %%
customer_name="rahul"
age=25
salary=55000.75
is_fraud=False
print(type(customer_name) )
print(type(age))
# Out:
# <class 'str'>
# <class 'int'>

# %%
#customer details
age=30
salary=55000.0
loan_amount=200000
existing_loans=2
credit_score=720
is_citizen=True

#---Arithmetic Operators ---
emi =loan_amount / 24 #monthly installment
total_income_yearly=salary*12
remaining_salary=total_income_yearly-(emi*12)

print("monthly EMI", emi)
print("yearly Income:", total_income_yearly)
print("remaining salary after EMI:" ,remaining_salary)
# Out:
# monthly EMI 8333.333333333334
# yearly Income: 660000.0
# remaining salary after EMI: 560000.0

# %%
item1=1200
item2=800
item3=600
discount=0.1
total=item1+item2+item3
final_bill=total-(total*discount)
print("total bill;" , total)
print("final bill after discount:" ,final_bill)
# Out:
# total bill; 2600
# final bill after discount: 2340.0

# %%
marks= int(input("enter your score:"))
if marks >= 90:
  print("grade: A (excellent)")
elif   marks >= 75:
    print("grade:B (good)")
elif marks >=60:
      print(" grade:c( needs improvement)")
else:
      print("grade:D(fail)")
# Out:
# enter your score:50
# grade:D(fail)

# %%
customers=["rahul", "priya","amit","sneha","vikram"]

for name in customers:
           print("sending email to:",name)
for i in range(1, 6):
  print("reminder email number", i)
# Out:
# sending email to: rahul
# sending email to: priya
# sending email to: amit
# sending email to: sneha
# sending email to: vikram
# reminder email number 1
# reminder email number 2
# reminder email number 3
# reminder email number 4
# reminder email number 5

# %%
student={"rahul":85, "priya":92, "amit":74}
for names, marks in student.items():
   if marks>=90:
      grade="A"
   elif marks>=75:
      grade= "B"
   else:
      grade="c"
   print(f"student: {name}, marks:{marks}, Grade:{grade}")
# Out:
# student: vikram, marks:85, Grade:B
# student: vikram, marks:92, Grade:A
# student: vikram, marks:74, Grade:c

# %%
def greet(name):
  print("hello", name, "welcome to the boot camp")
greet("rahul")
greet("priya")
# Out:
# hello rahul welcome to the boot camp
# hello priya welcome to the boot camp

# %%
def money(x,y):
  total=x+y
  return total
money(1000, 2000)
money("abc", "xyz")
# Out:
# 'abcxyz'

# %%
#eligiblecfor voting or not
def eligiblity(age):
  print(age)
  if age>=18:
   print ("ELIGIBLE FOE VOTING")
  else:
   print("NOT ELIGIBLE FOR VOTING")
eligiblity(19)
eligiblity(17)
# Out:
# 19
# ELIGIBLE FOE VOTING
# 17
# NOT ELIGIBLE FOR VOTING

# %%
#function to issue books
def issue_books(student_name, books):
  print(f"\n{student_name} borrowed)
  for book in books:
        print()"-", book)
  #function to calculate fine
  def calculate_fine(days_late):
    fine_per_day = 5
    return days_late * fine_per_day
    #function to generate report
  def student_report(student_name, book, days_late):
    issue_books(students_name,books)
    fine=clculate_fine(days_late)
    print(f"fine to be paid:$(fine)n")
  student_report("rahul", "python basics" , "data scince 101")
  student_report("priya" )
# Out:
#   File "/tmp/ipython-input-875/730999447.py", line 3
#     print(f"\n{student_name} borrowed)
#           ^
# SyntaxError: unterminated f-string literal (detected at line 3)

# %%
a = [10, 20, 30, 40, 50]
print(a[0])
print(a[-1])
print(a[1:4])
print(a[::2])
print(a[::-1])
# Out:
# 10
# 50
# [20, 30, 40]
# [10, 30, 50]
# [50, 40, 30, 20, 10]

# %%
print(a)
# Out:
# [10, 20, 30, 40, 50]

# %%
a.append(60)
print(a)
# Out:
# [10, 20, 30, 40, 50, 60]

# %%
a.extend([70,80])
print(a)
# Out:
# [10, 20, 30, 40, 50, 60, 70, 80]

# %%
a.insert(1, 15)
print(a)
# Out:
# [10, 15, 20, 30, 40, 50, 60, 70, 80]

# %%
a.remove(30)
print(a)
# Out:
# [10, 15, 20, 40, 50, 60, 70, 80]

# %%
val = a.pop()
print()

# %%
idx = a.index(40)
print(a)
# Out:
# [10, 15, 20, 40, 50, 60, 70]

# %%
count =a.count(20)
print(count)
# Out:
# 1

# %%
a.sort()
print(a)
# Out:
# [10, 15, 20, 40, 50, 60, 70]

# %%
b = sorted(a, reverse=True)
print(a)
# Out:
# [10, 15, 20, 40, 50, 60, 70]

# %%
a.reverse()
print(a)
# Out:
# [10, 15, 20, 40, 50, 60, 70]

# %%
squares = [x*x for x in range(6)]
squares
# Out:
# [0, 1, 4, 9, 16, 25]

# %%
evens = [x for x in range(10) if x % 2 == 0]
evens
# Out:
# [0, 2, 4, 6, 8]

# %%
pairs = [(i, j)for i in range(2) for j in range(2)]
pairs
# Out:
# [(0, 0), (0, 1), (1, 0), (1, 1)]

# %%
marks = [78, 85, 92,67,88]
marks.remove(min(marks))
marks
# Out:
# [78, 85, 92, 88]

# %%
marks.append(90)
marks
# Out:
# [78, 85, 92, 88, 90]

# %%
marks.sort(reverse=True)
marks
# Out:
# [92, 90, 88, 85, 78]

# %%
top_3 = marks [:3]
marks
# Out:
# [92, 90, 88, 85, 78]

# %%
average_top = sum(top_3)/ len(top_3)
marks
# Out:
# [92, 90, 88, 85, 78]

# %%
t = (1, 2, 3)
single = (42,)
packed = 1, 2, 3
print(t)
# Out:
# (1, 2, 3)

# %%
x, y, z = t
a, *mid, b = (1,2,3,4,5)
print(b)
# Out:
# 5

# %%
emp = {"id": 101,"name": "asha", "dept": "hr"}
alt = dict(id=101, name="asha", dept="HR")
empty = {}

# %%
emp["name"]
# Out:
# 'asha'

# %%
emp.get("email","")
# Out:
# ''

# %%
emp["salary"] = 70000

# %%
emp.update({"dept": "HR Analytics", "level": "senior"})

# %%
for k in emp:
  print(k)

for k, v in emp.items():
    print(k , v)

for v in emp.values():
      print(v)
# Out:
# id
# name
# dept
# salary
# level
# id 101
# name asha
# dept HR Analytics
# salary 70000
# level senior
# 101
# asha
# HR Analytics
# 70000
# senior

# %%
a ={"x": 1,"y":2}
b= {"y": 20, "z":3}
c= a | b
a |= b
print(a)
# Out:
# {'x': 1, 'y': 20, 'z': 3}

# %%
person = {"name":"Asha","addr":{"city":"pune","pin":411001}}
city = person.get("addr", {}).get("city")
print(city)
# Out:
# pune

# %%
set1 = (1,2,3,4,)
set2 = (3, 4, 5,6)

# %%
set1 = {1,2,3,4}
set1.add(10)
set1
# Out:
# {1, 2, 3, 4, 10}

# %%
import pandas as pd
import numpy as np

#sample dataset
data = {'name': ['alice', 'bob', 'charlie', 'david'],
        'Age':[25, np.nan, 30, np.nan],
        'Salary':[50000, 60000, None, 45000]}

df = pd.DataFrame(data)
print("before cleaning:\n", df)
# Out:
# before cleaning:
#        name   Age   Salary
# 0    alice  25.0  50000.0
# 1      bob   NaN  60000.0
# 2  charlie  30.0      NaN
# 3    david   NaN  45000.0

# %%
from os import setns

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
 #example data
data = [10, 12, 13 , 12, 11, 200, 14, 13,15, 12]
sns.boxplot(data)
plt.show()

#detcet using IQR
Q1, Q3=  np.percentile((data), [25,75])
IQR= Q3-Q1
